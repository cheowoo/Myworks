# %%
pip show openai
# Out:
# Name: openai
# Version: 1.99.9
# Summary: The official Python library for the openai API
# Home-page:
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: c:\users\campus1n005\documents\workspace-jcw2025\chatbot\ch01\.venv\lib\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 1: 필요한 패키지 설치 (최초 1회만 실행, 이미 설치되었다면 다음 단계 진행)
# !pip install python-dotenv

  #Step 2: 라이브러리 불러오기
from dotenv import load_dotenv
import os
 # Step 3: .env 파일 로드
# .env 파일이 현재 노트북(.ipynb)와 같은 폴더에 있어야 합니다.
load_dotenv()   #Step 4: 환경변수에서 API Key 가져오기
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")   #Step 5: 확인 (API Key는 보안상 끝 4자리만 출력)
if OPENAI_API_KEY:
    print(f"OPENAI_API_KEY 로드 성공: ...{OPENAI_API_KEY[-4:]}")
else:
    print("OPENAI_API_KEY를 찾을 수 없습니다. .env 파일을 확인하세요.")
# Out:
# OPENAI_API_KEY 로드 성공: ...AcwA

# %%
import openai

client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %%
# model : 사용할 LLM 지정
# messages : 대화 기록(역할 + 메시지)
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[{"role": "user", "content": "Tell me how to make a pizza, 한국어로 알려줘"}]
)

# 모델의 텍스트 응답만 출력
print(response.choices[0].message.content)
# Out:
# 다음은 기본적인 피자 만드는 법입니다. 한국어로 자세히 적었습니다. 필요하면 재료나 시간은 조절해도 좋습니다.
#
# 1) 재료(2판 정도, 2~3인분)
# - 밀가루: 500 g (강력분 권장)
# - 물: 320–340 ml
# - 드라이 이스트: 7 g (1 봉지)
# - 소금: 10 g
# - 올리브유: 15 ml
# - 선택: 설탕 1 작은술(이스트 활성에 도움), 토마토 소스 300–400 g, 모짜렐라 치즈 200–300 g, 올리브, 버섯, 바질 등 토핑
#
# 2) 도우 만들기
# - 큰 볼에 밀가루, 소금, 이스트를 섞습니다. 이스트가 소금과 직접 닿지 않도록 가볍게 분리해 두면 좋습니다.
# - 물과 올리브유를 조금씩 넣으며 반죽합니다. 처음엔 거칠하게, 점점 매끈하고 탄력 있게 반죽하세요.
# - 필요하면 반죽에 설탕을 1작은술 넣어도 됩니다. 반죽이 매끈하고 탄력 있어야 합니다.
# - 약 8–10분 정도 손으로 반죽해 글루이드를 만들고, 표면이 매끄럽고 탄력 있으면 완료입니다.
# - 반죽을 기름 약간 바른 그릇에 넣고 덮개나 랩으로 덮어 따뜻한 곳에서 1–2시간 정도 발효시켜 부풀게 합니다. 두 배가 되면 좋습니다.
# - 발효가 끝난 반죽에서 가스를 눌러 빼고(가볍게 펀칭), 필요에 따라 반으로 나눠 2개의 도우로 만듭니다. 각각 둥글게 모양을 잡고 약 15–20분 정도 휴지시키면 얇게 펼치기 쉽습니다.
#
# 3) 토핑 준비(소스 만들기)
# - 토마토 소스: 다진 토마토 캔 300–400 g에 다진 마늘 1쪽, 올리브유 1–2큰술, 소금, 바질이나 오레가노 같은 허브를 약간 넣습니다.
# - 간단 버전으로는 시판 피자 소스를 사용해도 좋습니다.
#
# 4) 피자 조립 및 굽기
# - 예열: 오븐을 250°C 이상으로 예열합니다. 가능하면 피자 스톤이나 두꺼운 철판을 예열하면 바닥이 더 바삭해집니다.
# - 도우 펼치기: 반죽을 손으로 눌러 원형으로 모양을 잡고, 밀가루를 살짝 뿌려 두껍지 않게 얇게 펼칩니다(두께 약 0.3–0.5 cm).
# - 도우 위에 올리브유를 살짝 발라 크러스트 가장자리가 예쁘게 올라오도록 합니다.
# - 소스 얹기: 도우 위에 토마토 소스를 고르게 바릅니다.
# - 토핑 얹기: 모짜렐라 치즈를 골고루 올리고, 원하는 토핑(버섯, 올리브, 페페로니, 양파, 바질 등)을 추가합니다.
# - 굽기: 예열된 오븐에 피자를 넣고 8–12분 정도 굽습니다. 가장자리가 황금빛이 되고 치즈가 녹아 거품이 생기면 완성입니다.
# - 바삭하게 원한다면 굽는 시간을 조금 더 늘리세요. 두꺼운 도우는 더 오래 필요합니다.
#
# 5) 팁
# - 피자 스톤이나 피자 스틸을 사용하면 바닥이 아주 바삭해집니다. 미리 예열하는 것이 중요합니다.
# - 반죽은 하루 전에 냉장고에서 천천히 발효시켜도 맛이 더 좋아집니다. 사용 전 실온에 30–60분 두었다가 펼치면 됩니다.
# - 토핑은 치즈가 녹고 어울리는 조합으로 가볍게 올리면 좋습니다. 너무 많은 토핑은 피자 아래가 잘 구워지지 않을 수 있습니다.
#
# 필요하면 채식 피자, 고기 피자, 또는 글루텐 프리 버전으로도 조정해 드릴게요. 원하는 스타일이나 재료를 알려주면 맞춤 레시피를 만들어 드리겠습니다.

# %%
# 토큰 사용량 출력
print(response.usage)

# 2025년 8월 기준 gpt-3.5-turbo 가격(USD)
INPUT_PRICE_PER_1K = 0.0015   # 입력(prompt) 1K tokens
OUTPUT_PRICE_PER_1K = 0.002   # 출력(completion) 1K tokens

# 총 비용(USD) 계산
total_bill_usd = (
    response.usage.prompt_tokens * INPUT_PRICE_PER_1K / 1000 +
    response.usage.completion_tokens * OUTPUT_PRICE_PER_1K / 1000
)

# USD → 원화 환산 (예시: 1 USD = 1323.43 KRW)
usd_to_krw = 1323.43
total_bill_krw = total_bill_usd * usd_to_krw

# 결과 출력
print(f"총 발생 비용: ${total_bill_usd:.6f} USD")
print(f"총 발생 비용: {total_bill_krw:.4f} 원")
# Out:
# CompletionUsage(completion_tokens=2347, prompt_tokens=19, total_tokens=2366, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=1344, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# 총 발생 비용: $0.004723 USD
# 총 발생 비용: 6.2499 원

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",  # 사용할 모델
    messages=[
        {"role": "system", "content": "너는 친절하게 답변해주는 비서야"},
        {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 2020년의 월드시리즈에서는 로스앤젤레스 다저스가 탬파베이 레이스를 4-2로 이기고 우승했어.

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You're a chatbot that refuses to answer and says sorry when users ask questions."},
        {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Sorry, I can't answer that.

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a translator who translates user input."},
        {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Who won the World Series in 2020?

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a chatbot that answers questions in English even in Korean."},
        {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# The Los Angeles Dodgers won the 2020 World Series.

# %%
# 필요 시 설치
# !pip install -U openai python-dotenv

from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 2002년 월드컵에서 가장 화제가 된 나라는 한국이었습니다. 한국은 자국에서 개최된 월드컵에서 준결승에 진출하며 엄청난 환호와 열기를 일으켰습니다. 특히, 한국 대표팀이 강력한 상대팀들을 이기며 기염을 토했던 것이 큰 화제가 되었죠. 이러한 성과로 한국은 많은 축구팬들의 관심을 받고 세계적인 주목을 받았습니다.
